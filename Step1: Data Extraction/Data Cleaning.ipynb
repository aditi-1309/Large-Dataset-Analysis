# %%
# Importing Pandas to work with dataframes
import pandas as pd

# %%
# Reading the CSV file with the dataset into stack_exchange
stack_exchange = pd.read_csv("D:\DCU\Academics\CA675 Cloud Tech\Assignment\Final_DataSet.csv")

# %%
# Checking the data of first five rows of stack_exchange
stack_exchange.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId      CreationDate  \
# 0    927358           1          927386.0       NaN  29-05-2009 18:09
# 1   2003505           1         2003515.0       NaN  05-01-2010 01:12
# 2   5767325           1         5767357.0       NaN  23-04-2011 22:17
# 3  16956810           1        16957078.0       NaN  06-06-2013 08:06
# 4   2906582           1         2906586.0       NaN  25-05-2010 16:39
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN  23303   10030841
# 1           NaN  18475    9258686
# 2           NaN   9899    8897394
# 3           NaN   6286    8203000
# 4           NaN   2298    7782563
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I accidentally <strong>committed the wrong ...      89904.0  ...
# 1  <p>I want to delete a branch both locally and ...      95592.0  ...
# 2  <p>I have an array of numbers and I'm using th...     364969.0  ...
# ...

# %%
# Understanding the columns of stack_exchange
stack_exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Id                     200000 non-null  int64
#  1   PostTypeId             200000 non-null  int64
#  2   AcceptedAnswerId       164180 non-null  float64
#  3   ParentId               0 non-null       float64
#  4   CreationDate           200000 non-null  object
#  5   DeletionDate           0 non-null       float64
#  6   Score                  200000 non-null  int64
#  7   ViewCount              200000 non-null  int64
#  8   Body                   200000 non-null  object
#  9   OwnerUserId            194802 non-null  float64
#  10  OwnerDisplayName       15281 non-null   object
#  11  LastEditorUserId       154872 non-null  float64
#  12  LastEditorDisplayName  9212 non-null    object
#  13  LastEditDate           156971 non-null  object
# ...

# %%
# Dropping columns ParentId and DeletionDate as they only have null values
to_drop = ['ParentId', 'DeletionDate']
stack_exchange.drop(columns=to_drop,inplace=True, axis=1)

# %%
# Checking if the columns are deleted properly
stack_exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Id                     200000 non-null  int64
#  1   PostTypeId             200000 non-null  int64
#  2   AcceptedAnswerId       164180 non-null  float64
#  3   CreationDate           200000 non-null  object
#  4   Score                  200000 non-null  int64
#  5   ViewCount              200000 non-null  int64
#  6   Body                   200000 non-null  object
#  7   OwnerUserId            194802 non-null  float64
#  8   OwnerDisplayName       15281 non-null   object
#  9   LastEditorUserId       154872 non-null  float64
#  10  LastEditorDisplayName  9212 non-null    object
#  11  LastEditDate           156971 non-null  object
#  12  LastActivityDate       199999 non-null  object
#  13  Title                  199999 non-null  object
# ...

# %%
# Importing regular experssion package
import re

# Function to remove HTML tags from the data
def remove_tag(data):
    clean_data = re.sub(pattern=re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});|\.*?'),repl='', string=str(data))
    return clean_data

# %%
# Creating a list by removing HTML tags from Title column
no_tag_title=[]
for i in range(len(stack_exchange.Title)):
    no_tag_title.append(remove_tag(stack_exchange.Title[i]))

# %%
# Creating a list by removing HTML tags from Body column
no_tag_body=[]
for i in range(len(stack_exchange.Body)):
    no_tag_body.append(remove_tag(stack_exchange.Body[i]))

# %%
print(no_tag_body[20])
print(stack_exchange.Body[20])
# Out:
# In SQL Server, it is possible to insert rows into a table with an INSERT SELECT statement:
# INSERT INTO Table (col1, col2, col3)
# SELECT col1, col2, col3
# FROM other_table
# WHERE sql = 'cool'
#
# Is it also possible to update a table with SELECT? I have a temporary table containing the values and would like to update another table using those values Perhaps something like this:
# UPDATE Table SET col1, col2
# SELECT col1, col2
# FROM other_table
# WHERE sql = 'cool'
# WHERE Tableid = other_tableid
#
#
# <p>In <strong>SQL Server</strong>, it is possible to insert rows into a table with an <code>INSERT.. SELECT</code> statement:</p>
# <pre><code>INSERT INTO Table (col1, col2, col3)
# SELECT col1, col2, col3
# FROM other_table
# WHERE sql = 'cool'
# </code></pre>
# <p>Is it also possible to <em>update</em> a table with <code>SELECT</code>? I have a temporary table containing the values and would like to update another table using those values. Perhaps something like this:</p>
# ...

# %%
# Dropping the columns Body and Title
stack_exchange.drop(['Body','Title'], axis = 1, inplace = True)

# %%
# Creating the columns Body and Title without the HTML tags
stack_exchange['Body'] = no_tag_body
stack_exchange['Title'] = no_tag_title

# Removing escape characters from Body and Title columns
stack_exchange['Body'] = stack_exchange['Body'].str.replace(r'\n|\t|\r','',regex=True)
stack_exchange['Title'] = stack_exchange['Title'].str.replace(r'\n|\t|\r','',regex=True)

# %%
stack_exchange.info()
stack_exchange.Title[6256]
stack_exchange.Body[6256]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Id                     200000 non-null  int64
#  1   PostTypeId             200000 non-null  int64
#  2   AcceptedAnswerId       164180 non-null  float64
#  3   CreationDate           200000 non-null  object
#  4   Score                  200000 non-null  int64
#  5   ViewCount              200000 non-null  int64
#  6   OwnerUserId            194802 non-null  float64
#  7   OwnerDisplayName       15281 non-null   object
#  8   LastEditorUserId       154872 non-null  float64
#  9   LastEditorDisplayName  9212 non-null    object
#  10  LastEditDate           156971 non-null  object
#  11  LastActivityDate       199999 non-null  object
#  12  Tags                   199999 non-null  object
#  13  AnswerCount            199999 non-null  float64
# ...

# %%
# Loading cleaned data to a CSV file
stack_exchange.to_csv(r'D:\DCU\Academics\CA675 Cloud Tech\Assignment\Cleaned_Final_DS_v2.csv',header=True,index=False)
